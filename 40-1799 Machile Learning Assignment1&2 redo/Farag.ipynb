# %%
import os 
import numpy as np
from matplotlib import pyplot
import pandas as pd

# %%
data=pd.read_csv("house_prices_data_training_data.csv")
columns =data.columns[3:]
norm_data = (data[columns]-(data[columns]).mean())/(data[columns]).std()
data[columns] = norm_data

# %%
train, validate , test = np.split(data.sample(frac=1),[int(.6*len(data)),int(.8*len(data))])

# %%
train = train.to_numpy()
test = test.to_numpy()
validate = validate.to_numpy()
train_x = train[:,3:]
validate_x = validate[:,3:]
test_x = test[:,3:]
train_y = train[:,2]
validate_y = validate[:,2]
test_y =test[:,2]
train_m =train_y.size

# %%
train_x = np.concatenate([np.ones((train_m,1)), train_x], axis =1)

# %%
def gradientDescentMulti(X, y, theta, alpha, num_iters):
    m = y.shape[0]
    theta = theta.copy()
    J_history = []
    for i in range(num_iters):
        theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
        J_history.append(computeCostMulti(X, y, theta))
    return theta, J_history

# %%
def computeCostMulti(X, y, theta):
    m = y.shape[0]
    J = 0
    h = np.dot(X, theta)
    J = (1/(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))
    return J

# %%
alpha = 0.03
num_iters = 400
theta2 = np.zeros(2)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:2], train_y, theta2, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 59614093527.04041

# %%
alpha = 0.03
num_iters = 400
theta3 = np.zeros(3)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:3], train_y, theta3, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 48628166222.95568

# %%
alpha = 0.03
num_iters = 400
theta4 = np.zeros(4)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:4], train_y, theta4, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 33213311221.188503

# %%
alpha = 0.03
num_iters = 400
theta5 = np.zeros(5)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:5], train_y, theta5, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 33124627272.521873

# %%
alpha = 0.03
num_iters = 400
theta6 = np.zeros(6)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:6], train_y, theta6, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 33124063876.643543

# %%
alpha = 0.03
num_iters = 400
theta7 = np.zeros(7)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:7], train_y, theta7, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 30394582399.23022

# %%
alpha = 0.03
num_iters = 400
theta8 = np.zeros(8)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:8], train_y, theta8, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 29533260793.669254

# %%
alpha = 0.03
num_iters = 400
theta9 = np.zeros(9)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:9], train_y, theta9, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 29094105082.824425

# %%
alpha = 0.03
num_iters = 400
theta10 = np.zeros(10)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:10], train_y, theta10, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 26826251008.118282

# %%
alpha = 0.03
num_iters = 400
theta11 = np.zeros(11)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:11], train_y, theta11, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 26928616688.57859

# %%
alpha = 0.03
num_iters = 400
theta12 = np.zeros(12)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:12], train_y, theta12, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 26801162115.25305

# %%
alpha = 0.03
num_iters = 400
theta13 = np.zeros(13)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:13], train_y, theta13, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 23136573638.066406

# %%
alpha = 0.03
num_iters = 400
theta14 = np.zeros(14)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:14], train_y, theta14, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 23110625840.130577

# %%
alpha = 0.03
num_iters = 400
theta15 = np.zeros(15)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:15], train_y, theta15, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 23099036552.565388

# %%
alpha = 0.03
num_iters = 400
theta16 = np.zeros(16)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:16], train_y, theta16, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 20359496960.862206

# %%
alpha = 0.03
num_iters = 400
theta17 = np.zeros(17)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:17], train_y, theta17, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 20167811614.927666

# %%
alpha = 0.03
num_iters = 400
theta18 = np.zeros(18)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:18], train_y, theta18, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
j_history[-1]
# Out:
# 20031266295.780495

# %%
alpha = 0.03
num_iters = 400
theta19 = np.zeros(19)
j_history=[]
u, j_history = gradientDescentMulti(train_x[:,0:19], train_y, theta19, alpha, num_iters) 
pyplot.plot(np.arange(len(j_history)), j_history, lw=2)
pyplot.xlabel('number of itierations')
pyplot.ylabel('Cost j')
# Out:
# Text(0, 0.5, 'Cost j')

# %%
u
# Out:
# array([533661.794138485, -33721.08016616917, 27481.061068218274,
#        79533.12304881384, 8009.9074557486565, 1175.5881689803211,
#        57636.870969002906, 34956.66229177121, 19167.1961587841,
#        99893.24090175869, 76617.57304369479, 22445.942936745065,
#        -80424.15093330429, 11915.020408282695, -30455.47041672955,
#        80247.55033463448, -28465.229587307393, 32536.370343012477,
#        -11944.065475878077], dtype=object)

# %%
j_history
# Out:
# [189672125091.75153,
#  175081519209.39285,
#  162566305301.55426,
#  151670966289.4937,
#  142060367464.47333,
#  133486097782.10875,
#  125762379293.9641,
#  118748810078.63818,
#  112337989164.14888,
#  106446630615.56807,
#  101009172545.67426,
#  95973171189.65405,
#  91295973104.55373,
#  86942303360.69543,
#  82882510941.26242,
#  79091286338.01768,
#  75546719000.08905,
#  72229599904.156,
#  69122901380.4661,
#  66211385526.42528,
#  63481306262.75438,
#  60920179902.41405,
#  58516606127.018166,
#  56260126296.560135,
#  54141109625.18968,
#  52150660344.50246,
#  50280540836.48957,
#  48523107057.941475,
#  46871253544.60079,
#  45318365982.4579,
#  43858279840.74746,
#  42485243930.5089,
#  41193888022.621445,
#  39979193857.75387,
#  38836469027.435844,
#  37761323314.78906,
#  36749647165.47807,
#  35797592021.59244,
#  34901552298.69699,
#  34058148823.03714,
#  33264213574.65828,
#  32516775604.95545,
#  31813048015.44065,
#  31150415899.33741,
#  30526425159.804863,
# ...

# %%
j_history[-1]
# Out:
# 19993031264.551205

# %%
alpha = 0.03
num_iters = 400
j_history = computeCostMulti(validate_x[:,0:2], validate_y, theta2)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:3], validate_y, theta3)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:4], validate_y, theta4)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:5], validate_y, theta5)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:6], validate_y, theta6)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:7], validate_y, theta7)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:8], validate_y, theta8)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:9], validate_y, theta9)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:10], validate_y, theta10)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:11], validate_y, theta11)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:12], validate_y, theta12)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:13], validate_y, theta13)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:14], validate_y, theta14)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:15], validate_y, theta15)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:16], validate_y, theta16)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:17], validate_y, theta17)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(validate_x[:,0:18], validate_y, theta18)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:2], test_y, theta2)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:3], test_y, theta3)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:4], test_y, theta4)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:5], test_y, theta5)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:6], test_y, theta6)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:7], test_y, theta7)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:8], test_y, theta8)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:9], test_y, theta9)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:10], test_y, theta10)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:11], test_y, theta11)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:12], test_y, theta12)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:13], test_y, theta13)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:14], test_y, theta14)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:15], test_y, theta15)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:16], test_y, theta16)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:17], test_y, theta17)

# %%
alpha = 0.03
num_iters = 400

j_history = computeCostMulti(test_x[:,0:18], test_y, theta18)
